# %%
import pandas as pd
import sqlite3
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
con = sqlite3.connect("../data/propriedades.db")

# %%
df = pd.read_sql("select * from dados", con)

# %%
con_2 = sqlite3.connect("ligantes_clauber.db")
ligantes = pd.read_sql("select * from ligantes_clauber", con_2)

# %%
ligantes
# Out:
#                                                  Smiles     logp    tpsa  \
# 0     CCCC1NC(=O)C(C(C)C)NC(=O)C(C(C)O)N(C)C(=O)C(C(...  1.18150  131.08
# 1     CNC(=O)c1ccc(CCNC(=O)C2CCCN2C(=O)CNC(=O)C2CC2c...  1.10810  127.84
# 2     N=C1CC(N2CC(NC(=O)C(Cc3ccc4ccccc4c3)NS(=O)(=O)...  1.39557  131.46
# 3     CCNC(=O)CNC(=O)C1(C(F)C2(C)CC2(Cl)Cl)CC(O)CN1C...  0.84950  136.04
# 4     CCSC1CC2CNC(=O)N(C(=O)C(Cc3ccccc3)NC(=O)C(NC(N...  2.49660  133.63
# ...                                                 ...      ...     ...
# 2202  CCC(C)(NCCCNCc1cccc(F)c1)C(=O)NC1C(=O)N2C(C(=O...  1.28510  131.08
# 2203  C=CCNC(=O)CC1NC2C(C(=O)N3CCCC3C(=O)NC(CC)CC)CC...  1.33210  110.85
# 2204  CCc1c(Cl)ccc(CC(NC(=O)C(N)Cc2c[nH]cn2)C(=O)N2C...  1.48900  133.21
# 2205  O=C1CCCN(C(=O)C(=O)NC(Cc2ccccc2)C(O)CNC(=O)c2c...  1.02200  127.84
# 2206  N=C(N=c1[nH]ccs1)NC(Cc1ccccc1)C(=O)N1CCN(C(=O)...  1.35337  130.67
#
#            molwt       qed  hba  hbd  active_probability
# 0     509.357720  0.407688    6    4            0.025474
# 1     506.252920  0.383918    5    4            0.004862
# 2     505.178375  0.343820    5    4            0.026046
# 3     497.149569  0.275038    5    4            0.000392
# 4     517.272276  0.378408    5    4            0.003619
# ...          ...       ...  ...  ...                 ...
# 2202  503.254397  0.264350    6    4            0.002152
# 2203  501.331505  0.413059    5    3            0.013842
# 2204  506.220845  0.408699    5    4            0.018219
# 2205  506.252920  0.417204    5    4            0.005340
# 2206  505.225994  0.285206    5    4            0.000250
#
# [2207 rows x 8 columns]
