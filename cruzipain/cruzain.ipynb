# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import pandas as pd
import sqlite3
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
import numpy as np
from matplotlib import pyplot as ptl
import seaborn as sns

# %%
con = sqlite3.connect("../data/chembl_29.db")

# %%
molregno_chembl_id = pd.read_sql_query("SELECT compound_properties.*, molecule_dictionary.chembl_id, compound_structures.canonical_smiles FROM compound_properties INNER JOIN compound_structures ON compound_structures.molregno=compound_properties.molregno INNER JOIN molecule_dictionary ON molecule_dictionary.molregno=compound_properties.molregno;", con)

# %%
molregno_chembl_id
# Out:
#          molregno  mw_freebase  alogp  hba  hbd     psa  rtb ro3_pass  \
# 0               1       341.75   2.11  5.0  1.0   84.82  3.0        N
# 1               2       332.32   1.33  6.0  1.0  108.61  3.0        N
# 2               3       357.80   2.27  5.0  2.0   87.98  3.0        N
# 3               4       307.31   1.46  5.0  1.0   84.82  3.0        N
# 4               5       341.75   2.11  5.0  1.0   84.82  3.0        N
# ...           ...          ...    ...  ...  ...     ...  ...      ...
# 2084719   2487510       556.38    NaN  NaN  NaN     NaN  NaN     None
# 2084720   2487511       378.30   3.13  3.0  2.0   58.36  5.0        N
# 2084721   2487512       356.42   2.29  5.0  4.0   90.82  7.0        N
# 2084722   2487513      1023.94    NaN  NaN  NaN     NaN  NaN     None
# 2084723   2487514       482.53   4.63  5.0  4.0   90.82  8.0        N
#
#          num_ro5_violations  cx_most_apka  ...  aromatic_rings  heavy_atoms  \
# 0                       0.0          6.48  ...             3.0         24.0
# 1                       0.0          6.33  ...             3.0         25.0
# 2                       0.0          6.33  ...             3.0         25.0
# 3                       0.0          6.33  ...             3.0         23.0
# 4                       0.0          6.33  ...             3.0         24.0
# ...                     ...           ...  ...             ...          ...
# 2084719                 NaN           NaN  ...             NaN          NaN
# 2084720                 0.0           NaN  ...             2.0         25.0
# 2084721                 0.0          9.18  ...             2.0         26.0
# 2084722                 NaN           NaN  ...             NaN          NaN
# 2084723                 0.0          9.19  ...             3.0         35.0
#
#          qed_weighted mw_monoisotopic  full_molformula  hba_lipinski  \
# 0                0.74        341.0567     C17H12ClN3O3           6.0
# 1                0.73        332.0909       C18H12N4O3           7.0
# 2                0.75        357.0880     C18H16ClN3O3           6.0
# 3                0.74        307.0957       C17H13N3O3           6.0
# 4                0.74        341.0567     C17H12ClN3O3           6.0
# ...               ...             ...              ...           ...
# 2084719           NaN        556.2055     C31H32BNO6P+           NaN
# 2084720          0.84        377.1062     C19H21Cl2N3O           4.0
# 2084721          0.57        356.1736       C20H24N2O4           6.0
# 2084722           NaN       1023.2919  C42H61FN3O17P3S           NaN
# 2084723          0.38        482.2017     C27H28F2N2O4           6.0
#
#          hbd_lipinski  num_lipinski_ro5_violations      chembl_id  \
# 0                 1.0                          0.0     CHEMBL6329
# 1                 1.0                          0.0     CHEMBL6328
# 2                 2.0                          0.0   CHEMBL265667
# 3                 1.0                          0.0     CHEMBL6362
# 4                 1.0                          0.0   CHEMBL267864
# ...               ...                          ...            ...
# 2084719           NaN                          NaN  CHEMBL4651250
# 2084720           3.0                          0.0  CHEMBL4651251
# 2084721           4.0                          0.0  CHEMBL4651252
# 2084722           NaN                          NaN  CHEMBL4651253
# 2084723           4.0                          0.0  CHEMBL4651254
#
#                                           canonical_smiles
# 0             Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccccc1Cl
# 1          Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(C#N)cc1
# 2         Cc1cc(-n2ncc(=O)[nH]c2=O)cc(C)c1C(O)c1ccc(Cl)cc1
# 3             Cc1ccc(C(=O)c2ccc(-n3ncc(=O)[nH]c3=O)cc2)cc1
# 4           Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(Cl)cc1
# ...                                                    ...
# 2084719  COc1ccc([P+](CCC(=O)Nc2ccc3c(c2)B(O)OC3)(c2ccc...
# 2084720   CNCc1ccc2c(c1)CN(C(=O)[C@H](N)Cc1ccc(Cl)cc1Cl)C2
# 2084721          Cc1ccc(CCCNCC(O)c2cc(O)cc3c2OCC(=O)N3)cc1
# 2084722  CCCCCCCCCCCCCCCCOC(=O)Oc1ccc(COP(=O)(OCc2ccc(O...
# 2084723  CC(C)(CC(c1ccc(F)cc1)c1ccc(F)cc1)NC[C@H](O)c1c...
#
# [2084724 rows x 25 columns]

# %%
cruzain_id = pd.read_csv('data/rhodesain.csv')
cruzain_id = cruzain_id["Molecule ChEMBL ID"]

# %%
data = molregno_chembl_id.query("chembl_id in @cruzain_id")
data.head()
# Out:
#        molregno  mw_freebase  alogp  hba  hbd     psa   rtb ro3_pass  \
# 3350       3965       340.43   2.88  4.0  4.0  118.20  10.0        N
# 25037     29061      1297.30    NaN  NaN  NaN     NaN   NaN     None
# 26938     31312       368.39   3.37  6.0  2.0   93.06   8.0        N
# 40771     47469       492.71   8.02  4.0  2.0   49.84  10.0        N
# 48439     56480       287.30   0.64  7.0  0.0  106.02   3.0        N
#
#        num_ro5_violations  cx_most_apka  ...  aromatic_rings  heavy_atoms  \
# 3350                  0.0           NaN  ...             2.0         25.0
# 25037                 NaN           NaN  ...             NaN          NaN
# 26938                 0.0          9.08  ...             2.0         27.0
# 40771                 1.0           NaN  ...             4.0         37.0
# 48439                 0.0           NaN  ...             1.0         19.0
#
#        qed_weighted mw_monoisotopic  full_molformula  hba_lipinski  \
# 3350           0.30        340.1899       C19H24N4O2           6.0
# 25037           NaN       1296.0469    C51H40N6O23S6           NaN
# 26938          0.55        368.1260         C21H20O6           6.0
# 40771          0.22        492.3253         C33H40N4           4.0
# 48439          0.46        287.0576      C10H13N3O5S           8.0
#
#        hbd_lipinski  num_lipinski_ro5_violations     chembl_id  \
# 3350            6.0                          1.0      CHEMBL55
# 25037           NaN                          NaN  CHEMBL265502
# 26938           2.0                          0.0     CHEMBL140
# 40771           2.0                          1.0   CHEMBL32823
# 48439           0.0                          0.0  CHEMBL290960
#
#                                         canonical_smiles
# 3350             N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1
# 25037  Cc1ccc(C(=O)Nc2ccc(S(=O)(=O)O)c3cc(S(=O)(=O)O)...
# 26938  COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O
# 40771  c1ccc2c(NCCCCCCCNc3c4c(nc5ccccc35)CCCC4)c3c(nc...
# 48439        CC1CS(=O)(=O)CCN1/N=C/c1ccc([N+](=O)[O-])o1
#
# [5 rows x 25 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
data.num_lipinski_ro5_violations.unique()
# Out:
# array([ 1., nan,  0.,  2.,  3.])

# %%
data.num_ro5_violations.unique()
# Out:
# array([ 0., nan,  1.,  2.,  3.])

# %%
molregno_chembl_id = data.copy()

# %%
molregno_chembl_id.loc[:, 'ro3_pass'] = molregno_chembl_id.loc[:, 'ro3_pass'].replace({"Y": 'True', "N": 'False'})
molregno_chembl_id.head()
# Out:
#        molregno  mw_freebase  alogp  hba  hbd     psa   rtb ro3_pass  \
# 3350       3965       340.43   2.88  4.0  4.0  118.20  10.0    False
# 25037     29061      1297.30    NaN  NaN  NaN     NaN   NaN     None
# 26938     31312       368.39   3.37  6.0  2.0   93.06   8.0    False
# 40771     47469       492.71   8.02  4.0  2.0   49.84  10.0    False
# 48439     56480       287.30   0.64  7.0  0.0  106.02   3.0    False
#
#        num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 3350                  0.0           NaN         12.13     2.32    -2.50
# 25037                 NaN           NaN           NaN      NaN      NaN
# 26938                 0.0          9.08           NaN     4.12     4.12
# 40771                 1.0           NaN          9.20     7.60     4.93
# 48439                 0.0           NaN          0.34    -0.27    -0.27
#
#       molecular_species  full_mwt  aromatic_rings  heavy_atoms  qed_weighted  \
# 3350               BASE    340.43             2.0         25.0          0.30
# 25037              None   1297.30             NaN          NaN           NaN
# 26938           NEUTRAL    368.39             2.0         27.0          0.55
# 40771              BASE    492.71             4.0         37.0          0.22
# 48439           NEUTRAL    287.30             1.0         19.0          0.46
#
#        mw_monoisotopic full_molformula  hba_lipinski  hbd_lipinski  \
# 3350          340.1899      C19H24N4O2           6.0           6.0
# 25037        1296.0469   C51H40N6O23S6           NaN           NaN
# 26938         368.1260        C21H20O6           6.0           2.0
# 40771         492.3253        C33H40N4           4.0           2.0
# 48439         287.0576     C10H13N3O5S           8.0           0.0
#
#        num_lipinski_ro5_violations     chembl_id  \
# 3350                           1.0      CHEMBL55
# 25037                          NaN  CHEMBL265502
# 26938                          0.0     CHEMBL140
# 40771                          1.0   CHEMBL32823
# 48439                          0.0  CHEMBL290960
#
#                                         canonical_smiles
# 3350             N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1
# 25037  Cc1ccc(C(=O)Nc2ccc(S(=O)(=O)O)c3cc(S(=O)(=O)O)...
# 26938  COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O
# 40771  c1ccc2c(NCCCCCCCNc3c4c(nc5ccccc35)CCCC4)c3c(nc...
# 48439        CC1CS(=O)(=O)CCN1/N=C/c1ccc([N+](=O)[O-])o1

# %%
molregno_chembl_id.query("num_lipinski_ro5_violations == 0")
# Out:
#          molregno  mw_freebase  alogp  hba  hbd     psa  rtb ro3_pass  \
# 26938       31312       368.39   3.37  6.0  2.0   93.06  8.0    False
# 48439       56480       287.30   0.64  7.0  0.0  106.02  3.0    False
# 50386       58841       182.17  -0.23  3.0  3.0   89.34  5.0    False
# 268526     309764       162.28   1.76  2.0  0.0   17.07  5.0    False
# 492108     549409       182.17  -0.23  3.0  3.0   89.34  5.0    False
# ...           ...          ...    ...  ...  ...     ...  ...      ...
# 2077001   2479569       423.54   3.45  5.0  1.0   81.06  8.0    False
# 2079390   2481960       460.60   4.76  4.0  2.0   75.27  8.0    False
# 2082086   2484657       456.55   4.38  6.0  1.0  106.38  9.0    False
# 2082195   2484766       416.57   2.75  5.0  2.0   75.27  8.0    False
# 2083499   2486071       420.53   3.73  4.0  1.0   76.13  9.0    False
#
#          num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 26938                   0.0          9.08           NaN     4.12     4.12
# 48439                   0.0           NaN          0.34    -0.27    -0.27
# 50386                   0.0          2.19         10.20    -2.91    -3.13
# 268526                  0.0           NaN           NaN     2.02     2.02
# 492108                  0.0          2.19         10.20    -2.91    -3.13
# ...                     ...           ...           ...      ...      ...
# 2077001                 0.0           NaN          4.73     2.89     2.89
# 2079390                 0.0           NaN          3.03     5.34     5.34
# 2082086                 0.0         12.11           NaN     4.75     4.75
# 2082195                 0.0         13.92          6.95     2.87     2.74
# 2083499                 0.0           NaN          4.33     3.88     3.88
#
#         molecular_species  full_mwt  aromatic_rings  heavy_atoms  \
# 26938             NEUTRAL    368.39             2.0         27.0
# 48439             NEUTRAL    287.30             1.0         19.0
# 50386          ZWITTERION    182.17             0.0         12.0
# 268526               None    162.28             0.0          9.0
# 492108         ZWITTERION    218.63             0.0         12.0
# ...                   ...       ...             ...          ...
# 2077001           NEUTRAL    423.54             3.0         30.0
# 2079390           NEUTRAL    460.60             3.0         33.0
# 2082086           NEUTRAL    456.55             3.0         31.0
# 2082195           NEUTRAL    416.57             2.0         28.0
# 2083499           NEUTRAL    420.53             3.0         30.0
#
#          qed_weighted  mw_monoisotopic full_molformula  hba_lipinski  \
# 26938            0.55         368.1260        C21H20O6           6.0
# 48439            0.46         287.0576     C10H13N3O5S           8.0
# 50386            0.55         182.0867     C6H12F2N2O2           4.0
# 268526           0.45         162.0173        C6H10OS2           1.0
# 492108           0.55         182.0867   C6H13ClF2N2O2           4.0
# ...               ...              ...             ...           ...
# 2077001          0.60         423.1617     C23H25N3O3S           6.0
# 2079390          0.51         460.1821     C27H28N2O3S           5.0
# 2082086          0.38         456.0814    C22H20N2O5S2           7.0
# 2082195          0.69         416.1228    C21H24N2O3S2           5.0
# 2083499          0.57         420.1508     C24H24N2O3S           5.0
#
#          hbd_lipinski  num_lipinski_ro5_violations      chembl_id  \
# 26938             2.0                          0.0      CHEMBL140
# 48439             0.0                          0.0   CHEMBL290960
# 50386             5.0                          0.0      CHEMBL830
# 268526            0.0                          0.0   CHEMBL359965
# 492108            5.0                          0.0   CHEMBL536971
# ...               ...                          ...            ...
# 2077001           1.0                          0.0  CHEMBL4643018
# 2079390           2.0                          0.0  CHEMBL4645409
# 2082086           1.0                          0.0  CHEMBL4648106
# 2082195           2.0                          0.0  CHEMBL4648215
# 2083499           1.0                          0.0  CHEMBL4649520
#
#                                           canonical_smiles
# 26938    COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O
# 48439          CC1CS(=O)(=O)CCN1/N=C/c1ccc([N+](=O)[O-])o1
# 50386                                NCCCC(N)(C(=O)O)C(F)F
# 268526                                 C=CCS[S+]([O-])CC=C
# 492108                            Cl.NCCCC(N)(C(=O)O)C(F)F
# ...                                                    ...
# 2077001  Cc1ncn(C)c1C(=O)N[C@H](/C=C/S(=O)(=O)c1ccccc1)...
# 2079390  O=C(N[C@H](/C=C/S(=O)(=O)c1ccccc1)CCc1ccccc1)c...
# 2082086  O=C(N[C@H](/C=C/S(=O)(=O)c1ccccc1)CCc1ccccc1)c...
# 2082195  O=C(N[C@H](/C=C/S(=O)(=O)c1ccccc1)CCc1ccccc1)[...
# 2083499  O=C(Cc1ccccn1)N[C@H](/C=C/S(=O)(=O)c1ccccc1)CC...
#
# [96 rows x 25 columns]

# %%
molregno_chembl_id.to_excel("rhodesain.xlsx")

# %%
warhead = molregno_chembl_id.query("canonical_smiles.str.contains('#')", engine="python")
warhead.head()
# Out:
#          molregno  mw_freebase  alogp  hba  hbd     psa   rtb ro3_pass  \
# 1722316   2093165       315.38   3.34  3.0  0.0   56.46   4.0    False
# 1722317   2093166       329.40   3.73  3.0  0.0   56.46   5.0    False
# 1722318   2093167       343.43   4.12  3.0  0.0   56.46   6.0    False
# 1840844   2227762       553.54   4.16  6.0  3.0  129.13   3.0    False
# 1843287   2230217       478.55   4.43  6.0  2.0  134.36  12.0    False
#
#          num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 1722316                 0.0           NaN          3.41     3.14     3.14
# 1722317                 0.0           NaN          3.47     3.59     3.59
# 1722318                 0.0           NaN          3.58     4.03     4.03
# 1840844                 1.0         11.07          2.29     3.70     3.70
# 1843287                 0.0         13.02           NaN     5.09     5.09
#
#         molecular_species  full_mwt  aromatic_rings  heavy_atoms  \
# 1722316           NEUTRAL    315.38             2.0         24.0
# 1722317           NEUTRAL    329.40             2.0         25.0
# 1722318           NEUTRAL    343.43             2.0         26.0
# 1840844           NEUTRAL    553.54             3.0         40.0
# 1843287           NEUTRAL    478.55             2.0         35.0
#
#          qed_weighted  mw_monoisotopic full_molformula  hba_lipinski  \
# 1722316          0.81         315.1372       C20H17N3O           4.0
# 1722317          0.62         329.1528       C21H19N3O           4.0
# 1722318          0.59         343.1685       C22H21N3O           4.0
# 1840844          0.45         553.1937    C28H26F3N5O4           9.0
# 1843287          0.26         478.2216      C26H30N4O5           9.0
#
#          hbd_lipinski  num_lipinski_ro5_violations      chembl_id  \
# 1722316           0.0                          0.0  CHEMBL3824277
# 1722317           0.0                          0.0  CHEMBL3822851
# 1722318           0.0                          0.0  CHEMBL3823624
# 1840844           3.0                          1.0  CHEMBL4087851
# 1843287           2.0                          0.0  CHEMBL4090306
#
#                                           canonical_smiles
# 1722316           N#C/C=C\CCN1C(=O)CN=C(c2ccccc2)c2ccccc21
# 1722317          N#C/C=C\CCCN1C(=O)CN=C(c2ccccc2)c2ccccc21
# 1722318         N#C/C=C\CCCCN1C(=O)CN=C(c2ccccc2)c2ccccc21
# 1840844  N#CC1(NC(=O)[C@@H]2Cc3ccc(c(-c4cc[nH]n4)c3)OCC...
# 1843287  CC(C)C[C@H](NC(=O)OCc1ccc([N+](=O)[O-])cc1)C(=...

# %%
warhead.query("num_lipinski_ro5_violations == 0").head()
# Out:
#          molregno  mw_freebase  alogp  hba  hbd     psa   rtb ro3_pass  \
# 1722316   2093165       315.38   3.34  3.0  0.0   56.46   4.0    False
# 1722317   2093166       329.40   3.73  3.0  0.0   56.46   5.0    False
# 1722318   2093167       343.43   4.12  3.0  0.0   56.46   6.0    False
# 1843287   2230217       478.55   4.43  6.0  2.0  134.36  12.0    False
#
#          num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 1722316                 0.0           NaN          3.41     3.14     3.14
# 1722317                 0.0           NaN          3.47     3.59     3.59
# 1722318                 0.0           NaN          3.58     4.03     4.03
# 1843287                 0.0         13.02           NaN     5.09     5.09
#
#         molecular_species  full_mwt  aromatic_rings  heavy_atoms  \
# 1722316           NEUTRAL    315.38             2.0         24.0
# 1722317           NEUTRAL    329.40             2.0         25.0
# 1722318           NEUTRAL    343.43             2.0         26.0
# 1843287           NEUTRAL    478.55             2.0         35.0
#
#          qed_weighted  mw_monoisotopic full_molformula  hba_lipinski  \
# 1722316          0.81         315.1372       C20H17N3O           4.0
# 1722317          0.62         329.1528       C21H19N3O           4.0
# 1722318          0.59         343.1685       C22H21N3O           4.0
# 1843287          0.26         478.2216      C26H30N4O5           9.0
#
#          hbd_lipinski  num_lipinski_ro5_violations      chembl_id  \
# 1722316           0.0                          0.0  CHEMBL3824277
# 1722317           0.0                          0.0  CHEMBL3822851
# 1722318           0.0                          0.0  CHEMBL3823624
# 1843287           2.0                          0.0  CHEMBL4090306
#
#                                           canonical_smiles
# 1722316           N#C/C=C\CCN1C(=O)CN=C(c2ccccc2)c2ccccc21
# 1722317          N#C/C=C\CCCN1C(=O)CN=C(c2ccccc2)c2ccccc21
# 1722318         N#C/C=C\CCCCN1C(=O)CN=C(c2ccccc2)c2ccccc21
# 1843287  CC(C)C[C@H](NC(=O)OCc1ccc([N+](=O)[O-])cc1)C(=...

# %%
import os, sys
sys.path.append("../module/")

# %%
from generate_pdb_gauss import *

# %%
alvos = warhead.query("num_lipinski_ro5_violations == 0")
alvos.to_excel("alvos_rhodesain.xlsx")

# %%
generate("rhodesain", alvos, 10)
# Out:
# <queue.Queue object at 0x7f776ae49fd0>

# %%
con.close()
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
