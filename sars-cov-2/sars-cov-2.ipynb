# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import pandas as pd
import sqlite3
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
import numpy as np
from matplotlib import pyplot as ptl
import seaborn as sns

# %%
con = sqlite3.connect("../data/chembl_29.db")

# %%
molregno_chembl_id = pd.read_sql_query("SELECT compound_properties.*, molecule_dictionary.chembl_id, compound_structures.canonical_smiles FROM compound_properties INNER JOIN compound_structures ON compound_structures.molregno=compound_properties.molregno INNER JOIN molecule_dictionary ON molecule_dictionary.molregno=compound_properties.molregno;", con)

# %%
molregno_chembl_id
# Out:
#          molregno  mw_freebase  alogp  hba  hbd     psa  rtb ro3_pass  \
# 0               1       341.75   2.11  5.0  1.0   84.82  3.0        N
# 1               2       332.32   1.33  6.0  1.0  108.61  3.0        N
# 2               3       357.80   2.27  5.0  2.0   87.98  3.0        N
# 3               4       307.31   1.46  5.0  1.0   84.82  3.0        N
# 4               5       341.75   2.11  5.0  1.0   84.82  3.0        N
# ...           ...          ...    ...  ...  ...     ...  ...      ...
# 2084719   2487510       556.38    NaN  NaN  NaN     NaN  NaN     None
# 2084720   2487511       378.30   3.13  3.0  2.0   58.36  5.0        N
# 2084721   2487512       356.42   2.29  5.0  4.0   90.82  7.0        N
# 2084722   2487513      1023.94    NaN  NaN  NaN     NaN  NaN     None
# 2084723   2487514       482.53   4.63  5.0  4.0   90.82  8.0        N
#
#          num_ro5_violations  cx_most_apka  ...  aromatic_rings  heavy_atoms  \
# 0                       0.0          6.48  ...             3.0         24.0
# 1                       0.0          6.33  ...             3.0         25.0
# 2                       0.0          6.33  ...             3.0         25.0
# 3                       0.0          6.33  ...             3.0         23.0
# 4                       0.0          6.33  ...             3.0         24.0
# ...                     ...           ...  ...             ...          ...
# 2084719                 NaN           NaN  ...             NaN          NaN
# 2084720                 0.0           NaN  ...             2.0         25.0
# 2084721                 0.0          9.18  ...             2.0         26.0
# 2084722                 NaN           NaN  ...             NaN          NaN
# 2084723                 0.0          9.19  ...             3.0         35.0
#
#          qed_weighted mw_monoisotopic  full_molformula  hba_lipinski  \
# 0                0.74        341.0567     C17H12ClN3O3           6.0
# 1                0.73        332.0909       C18H12N4O3           7.0
# 2                0.75        357.0880     C18H16ClN3O3           6.0
# 3                0.74        307.0957       C17H13N3O3           6.0
# 4                0.74        341.0567     C17H12ClN3O3           6.0
# ...               ...             ...              ...           ...
# 2084719           NaN        556.2055     C31H32BNO6P+           NaN
# 2084720          0.84        377.1062     C19H21Cl2N3O           4.0
# 2084721          0.57        356.1736       C20H24N2O4           6.0
# 2084722           NaN       1023.2919  C42H61FN3O17P3S           NaN
# 2084723          0.38        482.2017     C27H28F2N2O4           6.0
#
#          hbd_lipinski  num_lipinski_ro5_violations      chembl_id  \
# 0                 1.0                          0.0     CHEMBL6329
# 1                 1.0                          0.0     CHEMBL6328
# 2                 2.0                          0.0   CHEMBL265667
# 3                 1.0                          0.0     CHEMBL6362
# 4                 1.0                          0.0   CHEMBL267864
# ...               ...                          ...            ...
# 2084719           NaN                          NaN  CHEMBL4651250
# 2084720           3.0                          0.0  CHEMBL4651251
# 2084721           4.0                          0.0  CHEMBL4651252
# 2084722           NaN                          NaN  CHEMBL4651253
# 2084723           4.0                          0.0  CHEMBL4651254
#
#                                           canonical_smiles
# 0             Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccccc1Cl
# 1          Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(C#N)cc1
# 2         Cc1cc(-n2ncc(=O)[nH]c2=O)cc(C)c1C(O)c1ccc(Cl)cc1
# 3             Cc1ccc(C(=O)c2ccc(-n3ncc(=O)[nH]c3=O)cc2)cc1
# 4           Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(Cl)cc1
# ...                                                    ...
# 2084719  COc1ccc([P+](CCC(=O)Nc2ccc3c(c2)B(O)OC3)(c2ccc...
# 2084720   CNCc1ccc2c(c1)CN(C(=O)[C@H](N)Cc1ccc(Cl)cc1Cl)C2
# 2084721          Cc1ccc(CCCNCC(O)c2cc(O)cc3c2OCC(=O)N3)cc1
# 2084722  CCCCCCCCCCCCCCCCOC(=O)Oc1ccc(COP(=O)(OCc2ccc(O...
# 2084723  CC(C)(CC(c1ccc(F)cc1)c1ccc(F)cc1)NC[C@H](O)c1c...
#
# [2084724 rows x 25 columns]

# %%
cruzain_id = pd.read_csv('data/sars-cov-2.csv')
cruzain_id = cruzain_id["Molecule ChEMBL ID"]

# %%
data = molregno_chembl_id.query("chembl_id in @cruzain_id")
data.head()
# Out:
#      molregno  mw_freebase  alogp  hba  hbd     psa  rtb ro3_pass  \
# 75         97       383.41   1.78  8.0  1.0  106.95  4.0        N
# 92        115       162.24   1.85  2.0  0.0   16.13  1.0        Y
# 122       146       361.37   1.54  6.0  1.0   75.01  2.0        N
# 123       147       232.24   1.42  4.0  1.0   72.19  2.0        N
# 124       148       302.19   1.31  8.0  4.0  141.34  0.0        N
#
#      num_ro5_violations  cx_most_apka  ...  aromatic_rings  heavy_atoms  \
# 75                  0.0           NaN  ...             3.0         28.0
# 92                  0.0           NaN  ...             1.0         12.0
# 122                 0.0          5.29  ...             2.0         26.0
# 123                 0.0          4.37  ...             2.0         17.0
# 124                 0.0          5.54  ...             4.0         22.0
#
#      qed_weighted mw_monoisotopic  full_molformula  hba_lipinski  \
# 75           0.73        383.1594       C19H21N5O4           9.0
# 92           0.63        162.1157         C10H14N2           2.0
# 122          0.87        361.1438      C18H20FN3O4           7.0
# 123          0.85        232.0848       C12H12N2O3           5.0
# 124          0.22        302.0063          C14H6O8           8.0
#
#      hbd_lipinski  num_lipinski_ro5_violations   chembl_id  \
# 75            2.0                          0.0     CHEMBL2
# 92            0.0                          0.0     CHEMBL3
# 122           1.0                          0.0     CHEMBL4
# 123           1.0                          0.0     CHEMBL5
# 124           4.0                          0.0  CHEMBL6246
#
#                                      canonical_smiles
# 75      COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# 92                               CN1CCC[C@H]1c1cccnc1
# 122  CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 123                   CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 124        O=c1oc2c(O)c(O)cc3c(=O)oc4c(O)c(O)cc1c4c23
#
# [5 rows x 25 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
data.num_lipinski_ro5_violations.unique()
# Out:
# array([ 0.,  2.,  1.,  3., nan,  4.])

# %%
data.num_ro5_violations.unique()
# Out:
# array([ 0.,  2.,  1.,  3., nan,  4.])

# %%
molregno_chembl_id = data.copy()

# %%
molregno_chembl_id.loc[:, 'ro3_pass'] = molregno_chembl_id.loc[:, 'ro3_pass'].replace({"Y": 'True', "N": 'False'})
molregno_chembl_id.head()
# Out:
#      molregno  mw_freebase  alogp  hba  hbd     psa  rtb ro3_pass  \
# 75         97       383.41   1.78  8.0  1.0  106.95  4.0    False
# 92        115       162.24   1.85  2.0  0.0   16.13  1.0     True
# 122       146       361.37   1.54  6.0  1.0   75.01  2.0    False
# 123       147       232.24   1.42  4.0  1.0   72.19  2.0    False
# 124       148       302.19   1.31  8.0  4.0  141.34  0.0    False
#
#      num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 75                  0.0           NaN          7.24     1.65     1.43
# 92                  0.0           NaN          8.58     1.16    -0.04
# 122                 0.0          5.29          6.16     0.51    -0.47
# 123                 0.0          4.37          6.06     0.79    -0.45
# 124                 0.0          5.54           NaN     2.32    -0.53
#
#     molecular_species  full_mwt  aromatic_rings  heavy_atoms  qed_weighted  \
# 75            NEUTRAL    383.41             3.0         28.0          0.73
# 92               BASE    162.24             1.0         12.0          0.63
# 122              ACID    361.37             2.0         26.0          0.87
# 123              ACID    232.24             2.0         17.0          0.85
# 124              ACID    302.19             4.0         22.0          0.22
#
#      mw_monoisotopic full_molformula  hba_lipinski  hbd_lipinski  \
# 75          383.1594      C19H21N5O4           9.0           2.0
# 92          162.1157        C10H14N2           2.0           0.0
# 122         361.1438     C18H20FN3O4           7.0           1.0
# 123         232.0848      C12H12N2O3           5.0           1.0
# 124         302.0063         C14H6O8           8.0           4.0
#
#      num_lipinski_ro5_violations   chembl_id  \
# 75                           0.0     CHEMBL2
# 92                           0.0     CHEMBL3
# 122                          0.0     CHEMBL4
# 123                          0.0     CHEMBL5
# 124                          0.0  CHEMBL6246
#
#                                      canonical_smiles
# 75      COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# 92                               CN1CCC[C@H]1c1cccnc1
# 122  CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 123                   CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 124        O=c1oc2c(O)c(O)cc3c(=O)oc4c(O)c(O)cc1c4c23

# %%
molregno_chembl_id.query("num_lipinski_ro5_violations == 0")
# Out:
#          molregno  mw_freebase  alogp  hba  hbd     psa  rtb ro3_pass  \
# 75             97       383.41   1.78  8.0  1.0  106.95  4.0    False
# 92            115       162.24   1.85  2.0  0.0   16.13  1.0     True
# 122           146       361.37   1.54  6.0  1.0   75.01  2.0    False
# 123           147       232.24   1.42  4.0  1.0   72.19  2.0    False
# 124           148       302.19   1.31  8.0  4.0  141.34  0.0    False
# ...           ...          ...    ...  ...  ...     ...  ...      ...
# 2066358   2468877       208.26   1.54  3.0  1.0   46.53  5.0    False
# 2066359   2468878       145.16  -0.60  3.0  1.0   49.77  2.0     True
# 2066360   2468879       118.14   1.15  2.0  0.0   36.68  1.0     True
# 2066361   2468880       166.18   1.19  3.0  0.0   43.37  0.0     True
# 2066362   2468881       177.62   1.15  4.0  1.0   54.88  1.0    False
#
#          num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 75                      0.0           NaN          7.24     1.65     1.43
# 92                      0.0           NaN          8.58     1.16    -0.04
# 122                     0.0          5.29          6.16     0.51    -0.47
# 123                     0.0          4.37          6.06     0.79    -0.45
# 124                     0.0          5.54           NaN     2.32    -0.53
# ...                     ...           ...           ...      ...      ...
# 2066358                 0.0         12.70           NaN     2.13     2.13
# 2066359                 0.0          2.95          6.45    -2.67    -3.53
# 2066360                 0.0         12.65          4.16     0.84     0.84
# 2066361                 0.0           NaN           NaN     2.06     2.06
# 2066362                 0.0          6.95           NaN     0.58     0.06
#
#         molecular_species  full_mwt  aromatic_rings  heavy_atoms  \
# 75                NEUTRAL    383.41             3.0         28.0
# 92                   BASE    162.24             1.0         12.0
# 122                  ACID    361.37             2.0         26.0
# 123                  ACID    232.24             2.0         17.0
# 124                  ACID    302.19             4.0         22.0
# ...                   ...       ...             ...          ...
# 2066358           NEUTRAL    208.26             1.0         15.0
# 2066359              ACID    181.62             0.0         10.0
# 2066360           NEUTRAL    118.14             1.0          9.0
# 2066361              None    166.18             0.0         12.0
# 2066362           NEUTRAL    177.62             1.0         10.0
#
#          qed_weighted  mw_monoisotopic full_molformula  hba_lipinski  \
# 75               0.73         383.1594      C19H21N5O4           9.0
# 92               0.63         162.1157        C10H14N2           2.0
# 122              0.87         361.1438     C18H20FN3O4           7.0
# 123              0.85         232.0848      C12H12N2O3           5.0
# 124              0.22         302.0063         C14H6O8           8.0
# ...               ...              ...             ...           ...
# 2066358          0.75         208.1099        C12H16O3           3.0
# 2066359          0.56         145.0739      C6H12ClNO3           4.0
# 2066360          0.55         118.0531          C7H6N2           2.0
# 2066361          0.40         166.0630         C9H10O3           3.0
# 2066362          0.70         176.9764      C4H4ClN3OS           4.0
#
#          hbd_lipinski  num_lipinski_ro5_violations      chembl_id  \
# 75                2.0                          0.0        CHEMBL2
# 92                0.0                          0.0        CHEMBL3
# 122               1.0                          0.0        CHEMBL4
# 123               1.0                          0.0        CHEMBL5
# 124               4.0                          0.0     CHEMBL6246
# ...               ...                          ...            ...
# 2066358           1.0                          0.0  CHEMBL4630646
# 2066359           1.0                          0.0  CHEMBL4630647
# 2066360           0.0                          0.0  CHEMBL4630648
# 2066361           0.0                          0.0  CHEMBL4630649
# 2066362           1.0                          0.0  CHEMBL4630650
#
#                                          canonical_smiles
# 75          COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# 92                                   CN1CCC[C@H]1c1cccnc1
# 122      CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 123                       CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 124            O=c1oc2c(O)c(O)cc3c(=O)oc4c(O)c(O)cc1c4c23
# ...                                                   ...
# 2066358                        CCOC(=O)[C@H](O)CCc1ccccc1
# 2066359                                Cl.O=C(O)CN1CCOCC1
# 2066360                                      N#CCc1ccccn1
# 2066361                           CC1CCC2=C(C1)C(=O)OC2=O
# 2066362                                CC(=O)Nc1nnc(Cl)s1
#
# [5276 rows x 25 columns]

# %%
molregno_chembl_id.to_excel("rhodesain.xlsx")

# %%
warhead = molregno_chembl_id.query("canonical_smiles.str.contains('#')", engine="python")
warhead.head()
# Out:
#       molregno  mw_freebase  alogp  hba  hbd     psa   rtb ro3_pass  \
# 618        717       430.38   2.88  5.0  2.0  107.26   5.0    False
# 1046      1219       454.61   5.09  6.0  0.0   63.95  13.0    False
# 1375      1620       252.35   0.60  4.0  3.0   88.89   5.0    False
# 3557      4198        96.13   0.56  2.0  0.0   27.03   0.0     True
# 3730      4381       272.18   3.33  2.0  0.0   12.47   6.0    False
#
#       num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 618                  0.0         11.78           NaN     2.71     2.71
# 1046                 1.0           NaN          9.68     5.04     2.79
# 1375                 0.0         13.38          6.91    -0.11    -0.22
# 3557                 0.0           NaN           NaN     0.58     0.58
# 3730                 0.0           NaN          8.40     3.33     2.29
#
#      molecular_species  full_mwt  aromatic_rings  heavy_atoms  qed_weighted  \
# 618            NEUTRAL    430.38             2.0         29.0          0.56
# 1046              BASE    454.61             2.0         33.0          0.42
# 1375           NEUTRAL    252.35             1.0         17.0          0.23
# 3557              None     96.13             0.0          7.0          0.41
# 3730           NEUTRAL    272.18             1.0         17.0          0.58
#
#       mw_monoisotopic full_molformula  hba_lipinski  hbd_lipinski  \
# 618          430.0610   C18H14F4N2O4S           6.0           2.0
# 1046         454.2832      C27H38N2O4           6.0           0.0
# 1375         252.1157       C10H16N6S           6.0           3.0
# 3557          96.0687          C5H8N2           2.0           0.0
# 3730         271.0531     C13H15Cl2NO           2.0           0.0
#
#       num_lipinski_ro5_violations     chembl_id  \
# 618                           0.0     CHEMBL409
# 1046                          1.0    CHEMBL6966
# 1375                          0.0      CHEMBL30
# 3557                          0.0  CHEMBL262697
# 3730                          0.0    CHEMBL8706
#
#                                        canonical_smiles
# 618   CC(O)(CS(=O)(=O)c1ccc(F)cc1)C(=O)Nc1ccc(C#N)c(...
# 1046  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 1375                       CN/C(=N/CCSCc1nc[nH]c1C)NC#N
# 3557                                         N#CN1CCCC1
# 3730                         C#CCN(C)CCCOc1ccc(Cl)cc1Cl

# %%
warhead.query("num_lipinski_ro5_violations == 0").head()
# Out:
#       molregno  mw_freebase  alogp  hba  hbd     psa  rtb ro3_pass  \
# 618        717       430.38   2.88  5.0  2.0  107.26  5.0    False
# 1375      1620       252.35   0.60  4.0  3.0   88.89  5.0    False
# 3557      4198        96.13   0.56  2.0  0.0   27.03  0.0     True
# 3730      4381       272.18   3.33  2.0  0.0   12.47  6.0    False
# 4140      4920       223.28   2.68  3.0  0.0   41.61  1.0     True
#
#       num_ro5_violations  cx_most_apka  cx_most_bpka  cx_logp  cx_logd  \
# 618                  0.0         11.78           NaN     2.71     2.71
# 1375                 0.0         13.38          6.91    -0.11    -0.22
# 3557                 0.0           NaN           NaN     0.58     0.58
# 3730                 0.0           NaN          8.40     3.33     2.29
# 4140                 0.0           NaN          6.87     2.41     2.33
#
#      molecular_species  full_mwt  aromatic_rings  heavy_atoms  qed_weighted  \
# 618            NEUTRAL    430.38             2.0         29.0          0.56
# 1375           NEUTRAL    252.35             1.0         17.0          0.23
# 3557              None     96.13             0.0          7.0          0.41
# 3730           NEUTRAL    272.18             1.0         17.0          0.58
# 4140           NEUTRAL    223.28             2.0         17.0          0.75
#
#       mw_monoisotopic full_molformula  hba_lipinski  hbd_lipinski  \
# 618          430.0610   C18H14F4N2O4S           6.0           2.0
# 1375         252.1157       C10H16N6S           6.0           3.0
# 3557          96.0687          C5H8N2           2.0           0.0
# 3730         271.0531     C13H15Cl2NO           2.0           0.0
# 4140         223.1109        C14H13N3           3.0           0.0
#
#       num_lipinski_ro5_violations     chembl_id  \
# 618                           0.0     CHEMBL409
# 1375                          0.0      CHEMBL30
# 3557                          0.0  CHEMBL262697
# 3730                          0.0    CHEMBL8706
# 4140                          0.0    CHEMBL9298
#
#                                        canonical_smiles
# 618   CC(O)(CS(=O)(=O)c1ccc(F)cc1)C(=O)Nc1ccc(C#N)c(...
# 1375                       CN/C(=N/CCSCc1nc[nH]c1C)NC#N
# 3557                                         N#CN1CCCC1
# 3730                         C#CCN(C)CCCOc1ccc(Cl)cc1Cl
# 4140                         N#Cc1ccc(C2CCCc3cncn32)cc1

# %%
import os, sys
sys.path.append("../module/")

# %%
from generate_pdb_gauss import *

# %%
alvos = warhead.query("num_lipinski_ro5_violations == 0")
alvos.to_excel("alvos_rhodesain.xlsx")

# %%
generate("sars-cov-2", alvos, 4)
# Out:
# <queue.Queue object at 0x7fd773aa3df0>

# %%
con.close()
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 11 molecule converted
#  molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 17
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Error  in Do
#   3D coordinate generation failed
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 17
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 17
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 17
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 4 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 16 18
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 17
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 16
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Error  in Do
#   3D coordinate generation failed
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 6 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 5 8 10 1 19 4
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 9 10 23
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 9 10 20
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 18
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 18
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 2 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 14 1
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 9 10 21
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 17
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 1 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 19
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 1 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 16
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 6 7 16
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 1 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 14
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Error  in Do
#   3D coordinate generation failed
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 3 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 12 14 16
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in CorrectStereoAtoms
#   Could not correct 1 stereocenter(s) in this molecule ()
#   with Atom Ids as follows: 16
# Warning: Stereochemistry is wrong, using the distance geometry method instead
# 1 molecule converted
# 1 molecule converted
